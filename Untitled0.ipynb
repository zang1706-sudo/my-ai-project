# %% [markdown]
# <a href="https://colab.research.google.com/github/zang1706-sudo/my-ai-project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# Tải bộ dữ liệu chữ số viết tay
transform = transforms.Compose([transforms.ToTensor()])
trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)

# Hiển thị hình ảnh đầu tiên
image, label = trainset[0]
plt.imshow(image.squeeze(), cmap='gray')
plt.title(f"Label: {label}")
plt.show()
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 56.1MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.72MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.6MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.56MB/s]

# %%
import torch.nn as nn
import torch.optim as optim

# Tạo mô hình AI đơn giản
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc = nn.Linear(28*28, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        return self.fc(x)

model = SimpleNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Cho AI học 1 lần thử nghiệm
inputs = image.unsqueeze(0)
target = torch.tensor([label])

optimizer.zero_grad()
output = model(inputs)
loss = criterion(output, target)
loss.backward()
optimizer.step()

print(f"Đã học xong! Độ lỗi của AI (Loss): {loss.item():.4f}")
# Out:
# Đã học xong! Độ lỗi của AI (Loss): 2.3476
